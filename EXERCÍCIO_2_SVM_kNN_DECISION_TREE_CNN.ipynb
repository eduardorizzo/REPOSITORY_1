# %% [markdown]
# # Questões

# %% [markdown]
# ## Questão 1

# %% [markdown]
# Suponha que você esteja trabalhando na previsão do tempo e use um algoritmo de
# aprendizado para prever a temperatura de amanhã (em graus Centígrados/Fahrenheit). Você
# trataria isso como uma classificação ou um problema de regressão?
#
# R: Esse problema deve ser tratado como um problema de regressão, pois nesse caso estamos tentando prever um valor numerico contínuo no tempo. Conforme podemos encontrar no livro Thoughtful Machine Learning de Matthew Kirk, na tabela 2.2 onde mostra que o algoritmo (Kernel) Ridge Regression possui melhor desempenho com variaveis continuas.

# %% [markdown]
# ## Questão 2

# %% [markdown]
# Alguns dos problemas abaixo são mais bem resolvidos usando um algoritmo de aprendizagem supervisionado, e os outros com um algoritmo não supervisionado. Qual dos seguintes você aplicaria aprendizagem supervisionada? (Selecione todas que se apliquem.) Em cada caso, suponha que um conjunto de dados adequado está disponível para o seu algoritmo aprender.
# 1. Examine uma página da Web e classifique se o conteúdo da página deve ser considerado "amigável para crianças" ou "adulto".
# *R: Esse problema deve ser tratado como aprendizado supervisionado, pois a efetividade do algoritmo é muito importante, ou seja os falsos negativos devem ser evidados ao máximo. Apesar de ser um problema de classificação binária estou considerando que o conjunto de dados contenha a URL do site e sua classificação correta. Isso será utilizado para o aprendizado do classificador.
#
# 2. Dada uma base de dados sobre como 1.000 pacientes médicos respondem a um medicamento experimental (como eficácia do tratamento, efeitos colaterais, etc.), descubra se existem diferentes categorias ou "tipos" de pacientes em termos de como eles respondem ao medicamento e em caso afirmativo, quais são essas categorias.
# *R: Esse problema pode ser resolvido com aprendizado não supervisionado. Devido a sua caracteristica de formação de grupos de individuos que terão eficácias diferentes, efeitos colaterais diferentes e outros sintomas, deforma que o problema pode ser descrito com um classificador tipo k-Means por exemplo.
#
# 3. Na agricultura, com dados sobre o rendimento das colheitas nos últimos 50 anos, aprenda a prever os rendimentos das colheitas do próximo ano.
# *R: Esse é um problema de regressão, pois são dados contínos no tempo, de forma que esses valores devem ser obtidos com um aprendizado supervisionado. Pois problemas de regressão podem apresentar valores equivocos e é necessário um avaliador que possa verificar/informar quais são os valores corretos.
#
# 4. Dado um grande conjunto de dados de registros médicos de pacientes que sofrem de doenças cardíacas, tente descobrir se pode haver diferentes grupos desses pacientes para os quais podemos adaptar tratamentos separados.
# *R: Partindo do princípio que temos o bando de dados, podemos tratar esse problema em duas etapas, da qual a primeira etapa seria um problema de classificação e podemos adotar um algoritmo de classificação não supervisionada onde vamos separar os diferentes grupos de pacientes e uma segunda etapa também como um problema de classificação, porem dessa vez supervisionada onde vamos separar os tratamentos para cada tipo de grupo separado na etapa anteior.

# %% [markdown]
# ## Questão 3

# %% [markdown]
# Supondo que haja uma base de dados suficientemente grande para o treinamento de algum algoritmo. Assim, treinar utilizando uma grande quantidade de dados normalmente
# resulta em uma boa performance. Marque verdadeiro ou falso nas afirmações e justifique sua resposta:
# 1. As características contêm informação suficiente para prever a saída corretamente.
# *R: Falso, o numero elevado  de amostras geralmente contem ruido e outras negativas que devemos tratar antes de contruir o modelo.
#
# 2. Não é necessário utilizar regularização.
# *R: Falso, é uma boa prática a regularização, dessa forma podemos reduzir o orverfitting por exemplo.

# %% [markdown]
# ## Questão 4

# %% [markdown]
# Imagine que estamos trabalhando em um classificador de spam, onde e-mails de spam são exemplos positivos (saída igual a 1) e e-mails não spam são exemplos negativos (saída igual a zero). Nós temos uma base de dados de treinamento onde 99% dos e-mails não são spam e os outros 1% que são. Quais das afirmativas abaixo são verdadeiras?
# 1. Se predizermos tudo como não spam, a acurácia do classificador será 99%
# *R: Verdadeira. (VP+VN)/(VP+FN+VN+FP)
#
# 2. Se predizermos tudo como não spam, nosso classificador terá uma sensibilidade (recall) igual a 0%.
# *R:Falso, a sensibilidade será de 100% = VP/(VP+FN)
#
# 3. Se predizermos tudo como spam, o classificador terá uma sensibilidade de 100% e uma precisão de 1%.
# *R:Falso, ele continua com o a sensibilidade de 100% porque a sensibilidade representa o valor correto, mesmo errando ou outro 99 ele acertou o único que era spam.
#
# 4. Se predizermos tudo como spam, o classificador terá uma sensibilidade de 0% e uma precisão de 99%.
# *R:Falso, a sensibilidade ficam em 100% porem precisão fica em 1%.

# %% [markdown]
# ## Questão 5

# %% [markdown]
# Marque verdadeiro ou falso nas afirmativas abaixo.
# 1. Utilizar uma base de dados grande para o treinamento pode evitar o overfitting do classificador.
# *R: Verdade, mas o overfitting pode ocorrer em casos onde a quantidade de neuronios é maior que o necessário por exemplo.
#
# 2. Se ocorre o underfitting do algoritmo na base de treinamento, obter mais dados pode ajudar.
# *R:Verdade, podemos também utilizar técnicas com "data augmentation" para aumentar a quantidade de amostras.
#
# 3. O processo de análise manual dos exemplos que o algoritmo errou pode ajudar a sugerir os próximos passos para melhorar a performance do algoritmo (por exemplo, inserir novas características).
# *R: Falso. Nesse caso o melhor é analisar as métricas de avaliação como matriz de confusão, acurácia, precisão, F1-Score.
#
# 4. É uma boa ideia gastar bastante tempo na construção de uma base de dados suficientemente grande, antes de construir a primeira versão do algoritmo de aprendizado de máquinas.
# *R: Falso, pois existem metodos de avaliação do bando de dados que podemos aplicar para avaliar o bando de dados e melhorar caso necessário.

# %% [markdown]
# ## Questão 6

# %% [markdown]
# A figura 1 apresenta a função de custo 𝐽(𝜃0, 𝜃1) (“Plot 2”), assim como o contorno
# da mesma função (“Plot 1”). Baseado nas figuras, verifique quais das afirmativas abaixo são
# verdadeiras.

# %% [markdown]
# 1. Se partimos do ponto B, um algoritmo de gradiente descendente com um valor adequado de taxa de aprendizado ajudará a atingirmos o ponto A, onde a função de custo 𝐽(𝜃0, 𝜃1) possui seu valor máximo.
# *R: Falso, pois no ponto A é onde a derivada da função é igual a zero com isso a função custo tem seu valor mínimo, entretanto esse é o ponto  onde melhor podemos representar a função e ter o melhor desempenho no aprendizado do modelo.
# 2. Se partimos do ponto B, um algoritmo de gradiente descendente com um valor adequado de taxa de aprendizado ajudará a atingirmos o ponto A, onde a função de custo 𝐽(𝜃0, 𝜃1) possui seu valor mínimo.
# *R: Verdadeiro. Resposta anterior.
# 3. O ponto P (mínimo global no Plot 2) corresponde ao ponto A no Plot 1.
# *R: Correto, o Plot_1 é uma representação em um plano de duas dimenções da função representada pelo Plot_2.
# 4. Se partimos do ponto B, um algoritmo de gradiente descendente com um valor adequado de taxa de aprendizado ajudará a atingirmos o ponto C, onde a função de custo 𝐽(𝜃0, 𝜃1) possui seu valor mínimo.
# *R: Falso. O mínimo é o ponto A.
# 5. O ponto P (mínimo global no Plot 2) corresponde ao ponto C no Plot 1.
# *R: Falso.

# %% [markdown]
# ## Questão 7

# %% [markdown]
# Você roda um algoritmo de gradiente descendente por 15 interações com uma taxa de aprendizado 𝛼 = 0.3 e computa a perda 𝐽(𝜃) após cada iteração. Você observa que o valor de 𝐽(𝜃) aumenta ao longo do tempo. Baseado nisso, qual das sentenças abaixo parece mais plausível.
# 1. 𝛼 = 0.3 é um valor efetivo de taxa de aprendizado.
# *R:Falso.
# 2. Ao invés de se utilizar o valor corrente de 𝛼, é mais interessante aumentar seu valor (por exemplo, 𝛼 = 1.0).
# *R:Falso
# 3. Ao invés de se utilizar o valor corrente de 𝛼, é mais interessante diminuir seu valor (por exemplo, 𝛼 = 0.1).
# *R: Verdadeiro?

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# ## Código Exemplo PCA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import random
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#drive.mount('/content/drive')
random.seed(777)
print("The SEED is: ", random.random())
# Out:
# The SEED is:  0.22933408950153078

# %%
df = pd.read_csv('/content/drive/MyDrive/00.Mestrado/00.Disciplinas/01.Reconhecimento de Padrões/01.Exercício 2/cleveland.csv', header = None)

df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  target
# 0        3  0.0   6.0       0
# ...

# %%
### Mapeia as classes transformando o problema em binário
df['target'] = df.target.map({0: 0, 1: 1, 2: 1, 3: 1, 4: 1})
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  target
# 0        3  0.0   6.0       0
# ...

# %%
### Verifica se há valores nulos
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
### Substitui os valores nulos pela média ##
# Inserir aqui o codigo
df.fillna(df.mean(),inplace=True)

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
### Normaliza os dados ###############################
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
## Separa os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Treinamento Modelo
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Teste modelo
y_pred = classifier.predict(X_test)

# %%
# Resultados
cm_test = confusion_matrix(y_pred, y_test)
print(cm_test)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_test, y_test, cmap=plt.cm.Blues)
disp.ax_.set_title('Naive Bayes - Test')
print(disp.confusion_matrix)
plt.show()

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)
print(cm_train)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_train, y_train, cmap=plt.cm.Blues)
disp.ax_.set_title('Naive Bayes - Train')
print(disp.confusion_matrix)
plt.show()

print()
print('Accuracy for training set for Naive Bayes = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for Naive Bayes = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))
# Out:
# [[30  8]
#  [ 5 18]]
# [[30  5]
#  [ 8 18]]
# [[117  20]
#  [ 12  93]]
# [[117  12]
#  [ 20  93]]
# Accuracy for training set for Naive Bayes = 0.8677685950413223
# Accuracy for test set for Naive Bayes = 0.7868852459016393

# %% [markdown]
# ## KNN

# %% [markdown]
# ### KNN =3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import random
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier #KNEIGHSREGRESSITION...
from sklearn.metrics import confusion_matrix
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#drive.mount('/content/drive')
random.seed(777)
print("The SEED is: ", random.random())
# Out:
# The SEED is:  0.22933408950153078

# %%
df = pd.read_csv('/content/drive/MyDrive/00.Mestrado/00.Disciplinas/01.Reconhecimento de Padrões/01.Exercício 2/cleveland.csv', header = None)

df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
### Mapeia as classes transformando o problema em binário
df['target'] = df.target.map({0: 0, 1: 1, 2: 1, 3: 1, 4: 1})
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  target
# 0        3  0.0   6.0       0
# ...

# %%
### Verifica se há valores nulos
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
### Substitui os valores nulos pela média ##
# Inserir aqui o codigo
df.fillna(df.mean(),inplace=True)

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
### Normaliza os dados ###############################
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
## Separa os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
### Aplica KNN K = 3 #######################################

# Fitting classifier to the Training set
classifier = KNeighborsClassifier(n_neighbors = 3,p=2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Teste modelo
y_pred = classifier.predict(X_test)

# %%
# Resultados
cm_test = confusion_matrix(y_pred, y_test)
print(cm_test)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_test, y_test, cmap=plt.cm.Blues)
disp.ax_.set_title('KNM - Test')
print(disp.confusion_matrix)
plt.show()

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)
print(cm_train)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_train, y_train, cmap=plt.cm.Blues)
disp.ax_.set_title('KNM - Train')
print(disp.confusion_matrix)
plt.show()

print()
print('Accuracy for training set for KNN (k=3) = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for KNN (k=3) = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))
# Out:
# [[31  7]
#  [ 4 19]]
# [[31  4]
#  [ 7 19]]
# [[119  12]
#  [ 10 101]]
# [[119  10]
#  [ 12 101]]
# Accuracy for training set for KNN (k=3) = 0.9090909090909091
# Accuracy for test set for KNN (k=3) = 0.819672131147541

# %% [markdown]
# ### KNN =5

# %%
### Aplica KNN K = 5 #######################################

# Fitting classifier to the Training set
classifier = KNeighborsClassifier(n_neighbors = 5,p=2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Teste modelo
y_pred = classifier.predict(X_test)

# %%
# Resultados
cm_test = confusion_matrix(y_pred, y_test)
print(cm_test)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_test, y_test, cmap=plt.cm.Blues)
disp.ax_.set_title('KNM - Test')
print(disp.confusion_matrix)
plt.show()

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)
print(cm_train)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_train, y_train, cmap=plt.cm.Blues)
disp.ax_.set_title('KNM - Train')
print(disp.confusion_matrix)
plt.show()

print()
print('Accuracy for training set for KNN (k=5) = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for KNN (k=5) = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))
# Out:
# [[32  8]
#  [ 3 18]]
# [[32  3]
#  [ 8 18]]
# [[115  13]
#  [ 14 100]]
# [[115  14]
#  [ 13 100]]
# Accuracy for training set for KNN (k=5) = 0.8884297520661157
# Accuracy for test set for KNN (k=5) = 0.819672131147541

# %% [markdown]
# ### KNN = 7

# %%
### Aplica KNN K = 7 #######################################

# Fitting classifier to the Training set
classifier = KNeighborsClassifier(n_neighbors = 7,p=2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
# Teste modelo
y_pred = classifier.predict(X_test)

# %%
# Resultados
cm_test = confusion_matrix(y_pred, y_test)
print(cm_test)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_test, y_test, cmap=plt.cm.Blues)
disp.ax_.set_title('KNM - Test')
print(disp.confusion_matrix)
plt.show()

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)
print(cm_train)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_train, y_train, cmap=plt.cm.Blues)
disp.ax_.set_title('KNM - Train')
print(disp.confusion_matrix)
plt.show()

print()
print('Accuracy for training set for KNN (k=7) = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for KNN (k=7) = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))
# Out:
# [[32  9]
#  [ 3 17]]
# [[32  3]
#  [ 9 17]]
# [[115  14]
#  [ 14  99]]
# [[115  14]
#  [ 14  99]]
# Accuracy for training set for KNN (k=7) = 0.8842975206611571
# Accuracy for test set for KNN (k=7) = 0.8032786885245902

# %% [markdown]
# ## Árvore de Decisão

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import random
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier #KNEIGHSREGRESSITION...
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import tree
import matplotlib.pyplot as plt
#drive.mount('/content/drive')
random.seed(777)
print("The SEED is: ", random.random())
# Out:
# The SEED is:  0.22933408950153078

# %%
df = pd.read_csv('/content/drive/MyDrive/00.Mestrado/00.Disciplinas/01.Reconhecimento de Padrões/01.Exercício 2/cleveland.csv', header = None)

df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal', 'target']

features = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal']

# %%
### Mapeia as classes transformando o problema em binário
df['target'] = df.target.map({0: 0, 1: 1, 2: 1, 3: 1, 4: 1})
classes = ['doente','sadio']
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  target
# 0        3  0.0   6.0       0
# ...

# %%
### Verifica se há valores nulos
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
### Substitui os valores nulos pela média ##
# Inserir aqui o codigo
df.fillna(df.mean(),inplace=True)

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
### Normaliza os dados ###############################
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
## Separa os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
### Aplica ÁRVORE DE DECISÃO #######################################
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Teste modelo
y_pred = classifier.predict(X_test)

# %%
# Resultados
cm_test = confusion_matrix(y_pred, y_test)
print(cm_test)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_test, y_test, cmap=plt.cm.Blues)
disp.ax_.set_title('DECISION TREE - Test')
print(disp.confusion_matrix)
plt.show()

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)
print(cm_train)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_train, y_train, cmap=plt.cm.Blues)
disp.ax_.set_title('DECISION TREE - Train')
print(disp.confusion_matrix)
plt.show()

print()
print('Accuracy for training set for Decision tree = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for Decision tree = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

#plt the figure, setting a black background
plt.figure(figsize=(90,40), facecolor =None)
#create the tree plot
a = tree.plot_tree(classifier,
                   #use the feature names stored
                   feature_names = features,
                   #use the class names stored
                   class_names = classes,
                   rounded = True,
                   filled = True,
                   fontsize=14)
#show the plot
plt.show()
# Out:
# [[28  8]
#  [ 7 18]]
# [[28  7]
#  [ 8 18]]
# [[129   0]
#  [  0 113]]
# [[129   0]
#  [  0 113]]
# Accuracy for training set for Decision tree = 1.0
# Accuracy for test set for Decision tree = 0.7540983606557377
# Accuracy: 0.7540983606557377

# %% [markdown]
# ## SVM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import random
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier #KNEIGHSREGRESSITION...
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn import svm
from sklearn.decomposition import PCA
from sklearn.model_selection import LearningCurveDisplay, ShuffleSplit
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import tree
from sklearn.model_selection import LearningCurveDisplay, learning_curve
#drive.mount('/content/drive')
random.seed(777)
print("The SEED is: ", random.random())
# Out:
# The SEED is:  0.22933408950153078

# %%
df = pd.read_csv('/content/drive/MyDrive/00.Mestrado/00.Disciplinas/01.Reconhecimento de Padrões/01.Exercício 2/cleveland.csv', header = None)

df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal', 'target']

features = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal']

# %%
### Mapeia as classes transformando o problema em binário
df['target'] = df.target.map({0: 0, 1: 1, 2: 1, 3: 1, 4: 1})
classes = ['doente','sadio']
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  target
# 0        3  0.0   6.0       0
# ...

# %%
### Verifica se há valores nulos
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
### Substitui os valores nulos pela média ##
# Inserir aqui o codigo
df.fillna(df.mean(),inplace=True)

# %%
#X = df.iloc[:, :-1].values # CARACTERISTICAS TODAS MENOS A ULTIMA
#y = df.iloc[:, -1].values# CLASSE. SO A ULTIMA
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
### Normaliza os dados ###############################
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
## Separa os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
### Aplica Classificador SVM #######################################
classifier = svm.SVC(kernel='linear') # Linear Kernel
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Teste modelo
y_pred = classifier.predict(X_test)

# %%
# Resultados
cm_test = confusion_matrix(y_pred, y_test)
print(cm_test)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_test, y_test, cmap=plt.cm.Blues)
disp.ax_.set_title('SVM LINEAR - Test')
print(disp.confusion_matrix)
plt.show()

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)
print(cm_train)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_train, y_train, cmap=plt.cm.Blues)
disp.ax_.set_title('SVM LINEAR - Train')
print(disp.confusion_matrix)
plt.show()

print()
print('Accuracy for training set for SVM LINEAR = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for SVM LINEAR = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[31  9]
#  [ 4 17]]
# [[31  4]
#  [ 9 17]]
# [[115  21]
#  [ 14  92]]
# [[115  14]
#  [ 21  92]]
# Accuracy for training set for SVM LINEAR = 0.8553719008264463
# Accuracy for test set for SVM LINEAR = 0.7868852459016393
# Accuracy: 0.7868852459016393

# %%
### Aplica Classificador SVM #######################################
classifier = svm.SVC(kernel='rbf') # Linear Kernel
classifier.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Teste modelo
y_pred = classifier.predict(X_test)

# %%
# Resultados
cm_test = confusion_matrix(y_pred, y_test)
print(cm_test)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_test, y_test, cmap=plt.cm.Blues)
disp.ax_.set_title('SVM RBF - Test')
print(disp.confusion_matrix)
plt.show()

y_pred_train = classifier.predict(X_train)
cm_train = confusion_matrix(y_pred_train, y_train)
print(cm_train)

disp = ConfusionMatrixDisplay.from_estimator (classifier, X_train, y_train, cmap=plt.cm.Blues)
disp.ax_.set_title('SVM RBF - Train')
print(disp.confusion_matrix)
plt.show()

print()
print('Accuracy for training set for SVM RBF = {}'.format((cm_train[0][0] + cm_train[1][1])/len(y_train)))
print('Accuracy for test set for SVM RBF = {}'.format((cm_test[0][0] + cm_test[1][1])/len(y_test)))

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# [[32  9]
#  [ 3 17]]
# [[32  3]
#  [ 9 17]]
# [[124  13]
#  [  5 100]]
# [[124   5]
#  [ 13 100]]
# Accuracy for training set for SVM RBF = 0.9256198347107438
# Accuracy for test set for SVM RBF = 0.8032786885245902
# Accuracy: 0.8032786885245902

# %%
### Aplica PCA #######################################


pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)


scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

finalDf = pd.concat([principalDf, df[['target']]], axis = 1)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0, 1, 2, 3, 4]
colors = ['r', 'g', 'g', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

plt.figure(figsize=(8,6))
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6), sharey=True)
train_sizes, train_scores, test_scores = learning_curve(classifier, X, y)
common_params = {
    "X": X,
    "y": y,
    "train_sizes": train_sizes,
    "cv": ShuffleSplit(n_splits=50, test_size=0.2, random_state=0),
    "score_type": "both",
    "n_jobs": 4,
    "line_kw": {"marker": "o"},
    "std_display_style": "fill_between",
    "score_name": "Accuracy",
}

LearningCurveDisplay.from_estimator(classifier, **common_params, ax=ax)
handles, label = ax.get_legend_handles_labels()
ax.legend(handles[:2], ["Training Score", "Test Score"])
ax.set_title(f"Learning Curve for {classifier.__class__.__name__}")
# Out:
# Text(0.5, 1.0, 'Learning Curve for SVC')

# %% [markdown]
# ## COMPARAÇÃO DE RESULTADOS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import random
from sklearn.model_selection import cross_val_score # Cross Validation Function.
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier #KNEIGHSREGRESSITION...
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn import svm
from sklearn.decomposition import PCA
from sklearn.model_selection import LearningCurveDisplay, ShuffleSplit
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import tree
from sklearn.model_selection import LearningCurveDisplay, learning_curve
#drive.mount('/content/drive')
random.seed(777)
#random.seed()
print("The SEED is: ", random.random())


################################# 000000 #######################################
df = pd.read_csv('/content/drive/MyDrive/00.Mestrado/00.Disciplinas/01.Reconhecimento de Padrões/01.Exercício 2/cleveland.csv', header = None)

df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal', 'target']

features = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang',
              'oldpeak', 'slope', 'ca', 'thal']

### Mapeia as classes transformando o problema em binário
df['target'] = df.target.map({0: 0, 1: 1, 2: 1, 3: 1, 4: 1})
classes = ['doente','sadio']
#df

### Verifica se há valores nulos
#print(df.isnull().sum())

### Substitui os valores nulos pela média ##
# Inserir aqui o codigo
df.fillna(df.mean(),inplace=True)

#X = df.iloc[:, :-1].values # CARACTERISTICAS TODAS MENOS A ULTIMA
#y = df.iloc[:, -1].values# CLASSE. SO A ULTIMA
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

### Normaliza os dados ###############################
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

## Separa os dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
#########################################   Naive Bayes  #############################################################

# Treinamento Modelo
classifier = GaussianNB()
classifier.fit(X_train, y_train)

# Realizar a validação cruzada (k-fold = 10)
scores = cross_val_score(classifier, X, y, cv=10)

# Imprimir os resultados da validação cruzada
print("Acurácia Média Naive bayes: {:.2f}%".format(scores.mean() * 100))
print("Desvio Padrão Naive bayes: {:.2f}".format(scores.std()))

#########################################   kNN  #############################################################

# Criar o classificador kNN com k = 3
classifier_3 = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier_3.fit(X_train, y_train)

# Realizar a validação cruzada (k-fold = 10)
scores_kNN3 = cross_val_score(classifier_3, X, y, cv=10)

# Imprimir os resultados da validação cruzada
print("Acurácia Média kNN3: {:.2f}%".format(scores_kNN3.mean() * 100))
print("Desvio Padrão kNN3: {:.2f}".format(scores_kNN3.std()))

# Criar o classificador kNN com k = 5
classifier_5 = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier_5.fit(X_train, y_train)

# Realizar a validação cruzada (k-fold = 10)
scores_kNN5 = cross_val_score(classifier_5, X, y, cv=10)

# Imprimir os resultados da validação cruzada
print("Acurácia Média kNN5: {:.2f}%".format(scores_kNN5.mean() * 100))
print("Desvio Padrão kNN5: {:.2f}".format(scores_kNN5.std()))

# Criar o classificador kNN com k = 7
classifier_7 = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier_7.fit(X_train, y_train)

# Realizar a validação cruzada (k-fold = 10)
scores_kNN7 = cross_val_score(classifier_7, X, y, cv=10)

# Imprimir os resultados da validação cruzada
print("Acurácia Média kNN7: {:.2f}%".format(scores_kNN7.mean() * 100))
print("Desvio Padrão kNN7: {:.2f}".format(scores_kNN7.std()))

#########################################   Decision Tree  #############################################################
# Criar o classificador de árvore de decisão
clf = DecisionTreeClassifier()

# Realizar a validação cruzada (k-fold = 10)
scores_clf = cross_val_score(clf, X, y, cv=10)

# Imprimir os resultados da validação cruzada
print("Acurácia Média Decision tree: {:.2f}%".format(scores_clf.mean() * 100))
print("Desvio Padrão Decision tree: {:.2f}".format(scores_clf.std()))

######################################### Aplica Classificador SVM #######################################
classifier_SVM = svm.SVC(kernel='rbf') # RBF Kernel
classifier.fit(X_train, y_train)

# Realizar a validação cruzada (k-fold = 10)
scores_SVM = cross_val_score(classifier_SVM, X, y, cv=10)

# Imprimir os resultados da validação cruzada
print("Acurácia Média SVM: {:.2f}%".format(scores_SVM.mean() * 100))
print("Desvio Padrão SVM: {:.2f}".format(scores_SVM.std()))
# Out:
# The SEED is:  0.22933408950153078
# Acurácia Média Naive bayes: 84.80%
# Desvio Padrão Naive bayes: 0.06
# Acurácia Média kNN3: 63.37%
# Desvio Padrão kNN3: 0.09
# Acurácia Média kNN5: 63.37%
# Desvio Padrão kNN5: 0.09
# Acurácia Média kNN7: 67.00%
# Desvio Padrão kNN7: 0.09
# Acurácia Média Decision tree: 76.16%
# Desvio Padrão Decision tree: 0.09
# Acurácia Média SVM: 66.04%
# Desvio Padrão SVM: 0.08

# %% [markdown]
# # CNN

# %%
# TensorFlow e tf.keras
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import random
from sklearn.model_selection import cross_val_score # Cross Validation Function.
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier #KNEIGHSREGRESSITION...
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn import svm
from sklearn.decomposition import PCA
from sklearn.model_selection import LearningCurveDisplay, ShuffleSplit
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import tree
from sklearn.model_selection import LearningCurveDisplay, learning_curve
#drive.mount('/content/drive')
random.seed(777)
#random.seed()
print("The SEED is: ", random.random())
print(tf.__version__)
# Out:
# The SEED is:  0.22933408950153078
# 2.12.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images.shape
len(train_labels)

test_images.shape
len(test_labels)
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# 10000

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5017 - accuracy: 0.8245
# Epoch 2/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3779 - accuracy: 0.8634
# Epoch 3/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3380 - accuracy: 0.8765
# Epoch 4/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3144 - accuracy: 0.8848
# Epoch 5/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2946 - accuracy: 0.8924
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2827 - accuracy: 0.8953
# Epoch 7/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2693 - accuracy: 0.9007
# Epoch 8/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2598 - accuracy: 0.9025
# Epoch 9/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2496 - accuracy: 0.9064
# Epoch 10/50
# ...

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.4894 - accuracy: 0.8898 - 582ms/epoch - 2ms/step
#
# Test accuracy: 0.8898000121116638

# %%
predictions = model.predict(test_images)
predictions[0]
np.argmax(predictions[0])
test_labels[0]
# Out:
# 313/313 [==============================] - 0s 1ms/step
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)
  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

# %%
def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,  test_labels)
plt.show()

i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,  test_labels)
plt.show()

# %%
# Plota o primeiro X test images, e as labels preditas, e as labels verdadeiras.
# Colore as predições corretas de azul e as incorretas de vermelho.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)
plt.show()

# %%
# Grab an image from the test dataset.
img = test_images[0]

# %%
print(img.shape)
# Out:
# (28, 28)

# %%
# Adiciona a imagem em um batch que possui um só membro.
img = (np.expand_dims(img,0))

# %%
print(img.shape)

predictions_single = model.predict(img)

print(predictions_single)
# Out:
# (1, 28, 28)
# 1/1 [==============================] - 0s 14ms/step
# [[6.44902510e-16 3.97745520e-29 1.00921037e-19 6.35466087e-17
#   3.66190246e-19 5.23712410e-12 3.42934761e-19 2.81771690e-07
#   5.82236472e-16 9.99999762e-01]]

# %%
plot_value_array(0, predictions_single, test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

np.argmax(predictions_single[0])
# Out:
# 9

# %%
np.argmax(predictions_single[0])
# Out:
# 9
